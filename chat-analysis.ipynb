# %% [markdown]
# # Whatsapp Chat Analysis

# %% [markdown]
# ## Importing Libraries

# %%
import re

import numpy as np
import pandas as pd

# %% [markdown]
# ## Chat Analysis

# %% [markdown]
# ### Parsing Chat File

# %%
def isNewMessage(line: str):

    # We check for the first occurence of ':'
    first_col_index = line.find(':')

    # If ':' doesn't occur at all in the line, it's not a new message
    if first_col_index < 0:
        return [False, 0]
    
    # We check for the second occurence of ':'
    second_col_index = line.find(':', first_col_index+1) # The index of the first occurence of ':'

    # If ':' doesn't occur a second time in the line, it's not a new messages
    if second_col_index < 0:
        return [False, 0]

    # This matches the start of the line of new messages
    expression = '^(([0-9]|([0-9][0-9]))/([0-9]|([0-9][0-9]))/[0-9][0-9], (([0-9]|([0-9][0-9])):[0-9][0-9] (AM|PM)) - .*:)'

    # If the beginning of the line matches the exprsssion above, then it is a new message
    x = re.findall(expression, line[:second_col_index+1])

    if x:
        return [True, second_col_index]
    else: 
        return [False, 0]

# %%
def parseMessage(line: str, second_col_index) -> dict:
    # We extract the date, time, person and message based on the structure of lines in txt
    metadata = line[:second_col_index]
    message = line[second_col_index+2:]

    split1 = metadata.split(" - ")
    person = split1[1]

    split2 = split1[0].split(", ")
    date = split2[0]
    time = split2[1]

    return {'Date': date, 'Time': time, 'Person': person, 'Message': message}

# %%
chat_file = open('chat_st.txt', 'rt', encoding="utf8")

chat_df = pd.DataFrame(columns=['Date', 'Time', 'Person', 'Message'])

# rows will contain all the messages of the chat.
rows = []

lines = chat_file.readlines()

# Hold the current message when a message is spanning several lines
prevMessage: dict = {}

for line in lines[1:]:
    result = isNewMessage(line)

    isNew = result[0]
    col_index = result[1]

    # If the line is a new message
    # We save the previous message to the rows variable (list of messages)
    # and the new message becomes the previous message.
    if isNew:
        rows.append(prevMessage.values())
        prevMessage = parseMessage(line, col_index)
    else:
        # If the line is not a new message, that means it is part of the text of the previous message
        prevMessage['Message'] = prevMessage['Message'] + line

# Don't forget to add the last message to rows
rows.append(prevMessage.values())

# Create our chat dataframe for analysis
chat_df = pd.DataFrame(rows, columns=['Date', 'Time', 'Person', 'Message'])

chat_file.close()

# %%
# Ignore the first row
chat_df = chat_df.loc[1:]

chat_df = chat_df.reset_index(drop=True)

# %% [markdown]
# ### Chat Feature Engineering

# %%
people = chat_df['Person'].unique()

# %%
people
# Out:
# array(['Babila Mutia', 'ST'], dtype=object)

# %% [markdown]
# #### Date Features

# %%
chat_df['Date'] = pd.to_datetime(chat_df['Date'])

# %%
chat_df['DayOfWeek'] = chat_df['Date'].dt.day_name()

# %%
chat_df['MonthName'] = chat_df['Date'].dt.month_name()

# %%
chat_df['Year'] = chat_df['Date'].dt.year

# %% [markdown]
# #### Number of words

# %%
chat_no_media_df = chat_df.copy(deep=True)

# %%
chat_no_media_df = chat_no_media_df[chat_no_media_df['Message'] != '<Media omitted>\n']

# %%
chat_no_media_df['Words'] = chat_no_media_df['Message'].str.split()

# %%
lists = chat_no_media_df['Words'].tolist()

# For each message, we count its number of words
counts = [len(item) for item in lists]

# We add the new column for the number of words
chat_no_media_df['NumWords'] = counts

# %%
chat_no_media_df
# Out:
#            Date     Time        Person  \
# 0    2021-10-11  5:16 PM  Babila Mutia
# 1    2021-10-11  5:22 PM            ST
# 2    2021-10-11  5:22 PM            ST
# 3    2021-10-11  5:22 PM  Babila Mutia
# 4    2021-10-11  5:22 PM  Babila Mutia
# ...         ...      ...           ...
# 7265 2022-10-14  4:29 PM            ST
# 7266 2022-10-14  4:29 PM            ST
# 7267 2022-10-14  4:29 PM            ST
# 7268 2022-10-15  1:18 AM  Babila Mutia
# 7269 2022-10-15  1:18 AM  Babila Mutia
#
#                                         Message DayOfWeek MonthName  Year  \
# 0                                  I'm back 🌚\n    Monday   October  2021
# 1                                     😂😂😂😂😂😂😂\n    Monday   October  2021
# 2                    You repaired your phone?\n    Monday   October  2021
# 3                                          No\n    Monday   October  2021
# 4     I couldn't the screen was too expensive\n    Monday   October  2021
# ...                                         ...       ...       ...   ...
# 7265                                      Eh?\n    Friday   October  2022
# 7266                They took the one dollar?\n    Friday   October  2022
# 7267                     Let me try and check\n    Friday   October  2022
# 7268                                     Okay\n  Saturday   October  2022
# 7269                                   Yes ☹️\n  Saturday   October  2022
#
#                                                 Words  NumWords
# 0                                      [I'm, back, 🌚]         3
# 1                                           [😂😂😂😂😂😂😂]         1
# 2                       [You, repaired, your, phone?]         4
# 3                                                [No]         1
# 4     [I, couldn't, the, screen, was, too, expensive]         7
# ...                                               ...       ...
# 7265                                            [Eh?]         1
# 7266                  [They, took, the, one, dollar?]         5
# 7267                       [Let, me, try, and, check]         5
# 7268                                           [Okay]         1
# 7269                                        [Yes, ☹️]         2
#
# [6146 rows x 9 columns]

# %% [markdown]
# ### Chat Indicator Calculations

# %%
num_messages = {person: len(chat_df[chat_df['Person'] == person]) for person in people}
num_messages['total'] = len(chat_df)
num_messages
# Out:
# {'Babila Mutia': 3874, 'ST': 3396, 'total': 7270}

# %%
num_messages_nomedia = {person: len(chat_no_media_df[chat_no_media_df['Person'] == person]) for person in people}
num_messages_nomedia['total'] = len(chat_no_media_df)
num_messages_nomedia
# Out:
# {'Babila Mutia': 3338, 'ST': 2808, 'total': 6146}

# %%
num_words = {person: chat_no_media_df[chat_no_media_df['Person'] == person]['NumWords'].sum() for person in people}
num_words['total'] = chat_no_media_df['NumWords'].sum()
num_words
# Out:
# {'Babila Mutia': 17289, 'ST': 18481, 'total': 35770}

# %%
num_words_per_message = {person: 0 for person in people}

for person in chat_no_media_df['Person'].unique():
    num_words_per_message[person] = num_words[person] / num_messages_nomedia[person]

num_words_per_message['total'] = num_words['total'] / num_messages_nomedia['total']

num_words_per_message
# Out:
# {'Babila Mutia': 5.179448771719593,
#  'ST': 6.581552706552706,
#  'total': 5.82004555808656}

# %%
num_media = {person: 0 for person in people}

for person in chat_no_media_df['Person'].unique():
    num_media[person] = num_messages[person] - num_messages_nomedia[person]

num_media['total'] = num_messages['total'] - num_messages_nomedia['total']

num_media
# Out:
# {'Babila Mutia': 536, 'ST': 588, 'total': 1124}

# %%
chat_df.groupby(by='DayOfWeek', as_index=False).count().sort_values(by='Date', ascending=False)
# Out:
#    DayOfWeek  Date  Time  Person  Message  MonthName  Year
# 5    Tuesday  1381  1381    1381     1381       1381  1381
# 4   Thursday  1372  1372    1372     1372       1372  1372
# 1     Monday  1316  1316    1316     1316       1316  1316
# 6  Wednesday  1147  1147    1147     1147       1147  1147
# 0     Friday   938   938     938      938        938   938
# 3     Sunday   583   583     583      583        583   583
# 2   Saturday   533   533     533      533        533   533

# %%
print(people[0])

chat_df[chat_df['Person'] == people[0]].groupby(by='DayOfWeek', as_index=False).count().sort_values(by='Date', ascending=False)
# Out:
# Babila Mutia
#    DayOfWeek  Date  Time  Person  Message  MonthName  Year
# 4   Thursday   722   722     722      722        722   722
# 5    Tuesday   722   722     722      722        722   722
# 1     Monday   683   683     683      683        683   683
# 6  Wednesday   618   618     618      618        618   618
# 0     Friday   522   522     522      522        522   522
# 3     Sunday   316   316     316      316        316   316
# 2   Saturday   291   291     291      291        291   291

# %%
print(people[1])

chat_df[chat_df['Person'] == people[1]].groupby(by='DayOfWeek', as_index=False).count().sort_values(by='Date', ascending=False)
# Out:
# ST
#    DayOfWeek  Date  Time  Person  Message  MonthName  Year
# 5    Tuesday   659   659     659      659        659   659
# 4   Thursday   650   650     650      650        650   650
# 1     Monday   633   633     633      633        633   633
# 6  Wednesday   529   529     529      529        529   529
# 0     Friday   416   416     416      416        416   416
# 3     Sunday   267   267     267      267        267   267
# 2   Saturday   242   242     242      242        242   242

# %%
chat_df.groupby(by=['Year', 'MonthName'], as_index=False).count().sort_values(by='Date', ascending=False)
# Out:
#     Year  MonthName  Date  Time  Person  Message  DayOfWeek
# 2   2021    October   983   983     983      983        983
# 5   2022   February   815   815     815      815        815
# 1   2021   November   800   800     800      800        800
# 0   2021   December   775   775     775      775        775
# 6   2022    January   611   611     611      611        611
# 9   2022      March   556   556     556      556        556
# 10  2022        May   521   521     521      521        521
# 12  2022  September   463   463     463      463        463
# 4   2022     August   453   453     453      453        453
# 3   2022      April   430   430     430      430        430
# 7   2022       July   430   430     430      430        430
# 11  2022    October   270   270     270      270        270
# 8   2022       June   163   163     163      163        163

# %%
vocabulary = {}

for person in people:
    vocabulary[person] = {}

# %%
from typing import List


def stripWord(chars: List[str], word: str):
    for char in chars:
        word = word.replace(char, '')

    return word

# %%
def countWords(row):
    for word in row['Words']:
        word = stripWord({',','!','?',':',';','.'}, word)
        if word in vocabulary[row['Person']]:
            vocabulary[row['Person']][word] += 1
        else:
            vocabulary[row['Person']][word] = 1

# %%
chat_no_media_df.apply(countWords, axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 7265    None
# 7266    None
# 7267    None
# 7268    None
# 7269    None
# Length: 6146, dtype: object

# %%
vocabulary
# Out:
# {'Babila Mutia': {"I'm": 86,
#   'back': 15,
#   '🌚': 253,
#   'No': 55,
#   'I': 275,
#   "couldn't": 5,
#   'the': 535,
#   'screen': 4,
#   'was': 211,
#   'too': 41,
#   'expensive': 2,
#   'it': 293,
#   'same': 21,
#   'price': 1,
#   'as': 20,
#   'new': 14,
#   'phone': 9,
#   'just': 146,
#   'bought': 7,
#   'one': 52,
#   'It': 24,
#   '150k': 1,
#   'A': 3,
#   'samsung': 1,
#   's10': 1,
#   '😂😂😂😂': 3,
#   'ha': 29,
#   'ah*': 1,
#   'tsiups': 136,
#   '😂😂😂': 1,
#   'Well': 7,
#   "it's": 158,
#   'not': 77,
#   'Yes': 74,
#   'But': 74,
#   'they': 141,
#   'have': 106,
#   'nt': 87,
#   'yet': 15,
#   'started': 17,
#   'paying': 2,
#   'me': 74,
#   'saved': 3,
#   'up': 15,
#   'money': 12,
#   'Its': 8,
#   '200k': 1,
#   'for': 87,
#   'now': 23,
#   'yes': 145,
#   'still': 32,
#   'working': 2,
#   'there': 62,
#   'lost': 4,
#   'all': 60,
#   'my': 31,
#   'stickers': 1,
#   '😭😭😭😭': 2,
#   'tsuips': 1,
#   "You'll": 10,
#   'send': 16,
#   'of': 146,
#   'yours': 1,
#   'n': 1,
#   '😹😹😹😹': 210,
#   'why': 74,
#   'are': 107,
#   'people': 47,
#   'like': 125,
#   'this': 49,
#   '😹': 505,
#   'rien': 1,
#   'what': 85,
#   'did': 35,
#   'think': 43,
#   '😹😹😹': 362,
#   '😹😹': 348,
#   'okay': 170,
#   'ur': 24,
#   'at': 30,
#   'school': 14,
#   'then': 53,
#   'he': 94,
#   'left': 5,
#   'u': 97,
#   'that': 265,
#   'when': 51,
#   'brother': 3,
#   'called': 4,
#   'in': 156,
#   'class': 5,
#   '😹😹😹😹😹😹😹😹😹😹😹😹😹😹😹': 2,
#   "that's": 100,
#   'horrible': 5,
#   '😹😹😹😹😹': 101,
#   'abuse': 1,
#   'ahn': 15,
#   'AI': 5,
#   'is': 176,
#   'screaming': 2,
#   'which': 3,
#   'language': 2,
#   'you': 235,
#   'using': 6,
#   'ahnnn': 14,
#   'how': 54,
#   'easy': 2,
#   'great': 7,
#   'nice': 63,
#   'eh': 25,
#   'Ha': 11,
#   'ah': 36,
#   '': 12,
#   'putting': 2,
#   'black': 4,
#   'moon': 6,
#   "you're": 18,
#   'even': 67,
#   'making': 9,
#   'sense': 14,
#   'no': 127,
#   'dnt': 42,
#   'internet': 7,
#   'sure': 13,
#   'to': 261,
#   'buy': 5,
#   'a': 186,
#   'bundle': 1,
#   'month': 2,
#   'since': 14,
#   'if': 47,
#   'mummy': 2,
#   'gives': 1,
#   'maybe': 16,
#   '😭😭': 5,
#   'notre': 1,
#   'héro': 1,
#   'solitaire': 1,
#   "s'aventura": 1,
#   'dans': 1,
#   'le': 3,
#   'désert': 1,
#   'pour': 1,
#   'accomplir': 1,
#   'sa': 2,
#   'destinée': 1,
#   'malheureusement': 1,
#   'il': 1,
#   'fut': 1,
#   'anéanti': 1,
#   'par': 1,
#   'son': 1,
#   'ennemi': 1,
#   'juré': 1,
#   'un': 4,
#   'chat': 2,
#   'rouge': 2,
#   'Le': 1,
#   'couleur': 1,
#   'était': 1,
#   'faiblesse': 1,
#   'Because': 8,
#   'hero': 1,
#   'must': 1,
#   'weakness': 1,
#   '🌚🌚🌚': 1,
#   'these': 16,
#   'pillars': 1,
#   'storytelling': 1,
#   '😹😹😹😹😹😹😹😹😹': 14,
#   'From': 3,
#   'Phineas': 1,
#   'and': 195,
#   'Ferb': 2,
#   'na': 64,
#   'fighting': 7,
#   'monster': 1,
#   'or': 27,
#   'something': 23,
#   'narrator': 1,
#   '😹😹😹😹😹😹': 50,
#   '"Non': 1,
#   "j'avais": 1,
#   'tort"': 1,
#   'ahnnnnn': 1,
#   'remember': 13,
#   'ehhhh': 5,
#   'M': 7,
#   'world': 9,
#   'lucky': 2,
#   'has': 27,
#   'retired': 1,
#   'oh': 83,
#   'ohhh': 2,
#   'ignorance': 1,
#   'their': 15,
#   'doom': 1,
#   'The': 41,
#   'teacher': 5,
#   'terrible': 52,
#   '😹😹😹😹😹😹😹': 33,
#   'understand': 12,
#   'downloaded': 1,
#   "n'a": 113,
#   'some': 8,
#   'nature': 3,
#   'wallpapers': 1,
#   'link': 3,
#   'please': 3,
#   'connection': 2,
#   'office': 10,
#   'today': 8,
#   '🤦🏾\u200d♂️': 22,
#   '😹😹tsiups': 2,
#   'ahnn': 45,
#   'okau': 1,
#   "I'll": 46,
#   'search': 2,
#   'long': 9,
#   'only': 32,
#   'pple': 33,
#   'hv': 13,
#   'read': 10,
#   'manga': 6,
#   'hype': 9,
#   'bc': 34,
#   'short': 6,
#   'so': 49,
#   'we': 36,
#   'know': 63,
#   'expect': 2,
#   'end': 8,
#   'season': 9,
#   "there's": 29,
#   'apart': 2,
#   '4rm': 2,
#   'fight': 5,
#   'between': 8,
#   'Eren': 18,
#   'Reimer': 1,
#   'any': 12,
#   'Except': 1,
#   'those': 18,
#   'who': 8,
#   '🌚🌚🌚🌚🌚🌚': 1,
#   'talking': 7,
#   'about': 31,
#   'kind': 8,
#   'thing': 18,
#   'readers': 2,
#   'nothing': 9,
#   '😹😹😹tsiups': 3,
#   "she's": 4,
#   'stalker': 1,
#   'change': 3,
#   'schools': 1,
#   'do': 63,
#   'shootings': 2,
#   'start': 6,
#   '😹😹😹😹😹😹😹l': 1,
#   'she': 23,
#   'will': 83,
#   'age': 2,
#   'try': 14,
#   'eliminate': 1,
#   'first': 13,
#   '2': 16,
#   'be': 65,
#   'on': 61,
#   'guard': 2,
#   'can': 69,
#   'with': 55,
#   'Nathaniel': 2,
#   'hw': 4,
#   'communicate': 1,
#   'cannot': 18,
#   'talk': 5,
#   'noo': 18,
#   '😹😹😹😹😹😹😹😹😹😹😹😹': 1,
#   'Why': 15,
#   'should': 16,
#   'come': 13,
#   'Are': 4,
#   'room': 7,
#   'accusing': 1,
#   'je': 1,
#   'vais': 3,
#   "t'enfermer": 1,
#   'Have': 5,
#   'ever': 10,
#   'said': 23,
#   'friend': 7,
#   'Just': 6,
#   'go': 19,
#   'whisper': 1,
#   'his': 27,
#   'ear': 1,
#   '"Je': 1,
#   'te': 3,
#   'robam"': 1,
#   'Or': 6,
#   'someone': 12,
#   "doesn't": 9,
#   'knows': 4,
#   'its': 17,
#   'joke': 1,
#   'Okay': 57,
#   'forget': 3,
#   'record': 2,
#   'wanted': 7,
#   'show': 8,
#   'Daddy': 7,
#   'playing': 8,
#   'chess': 3,
#   'online': 2,
#   'So': 23,
#   'i': 16,
#   'put': 10,
#   'game': 30,
#   'man': 8,
#   'winning': 2,
#   'finally': 3,
#   'won': 4,
#   '\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾': 11,
#   'had': 33,
#   'flashback': 1,
#   'during': 5,
#   'match': 4,
#   'could': 15,
#   'let': 12,
#   'down': 2,
#   'Then': 28,
#   'made': 21,
#   'telling': 58,
#   "s'en": 1,
#   'come-back': 1,
#   '\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾': 18,
#   'sprained': 2,
#   'ankle': 2,
#   'court': 1,
#   'went': 4,
#   'layup': 1,
#   'instead': 8,
#   'landing': 1,
#   'foot': 1,
#   'landed': 2,
#   'shocked': 2,
#   'Which': 3,
#   'her': 25,
#   'leg': 2,
#   'but': 87,
#   "I've": 22,
#   'forgotten': 5,
#   'ehh': 3,
#   'You': 44,
#   'skateboard': 1,
#   'jump': 2,
#   'Ashia': 6,
#   'How': 7,
#   'much': 11,
#   'were': 56,
#   'skateboarding': 1,
#   'friends': 2,
#   'skate': 1,
#   'board': 1,
#   'running': 1,
#   'push': 3,
#   'once': 4,
#   'while': 2,
#   'ahh': 1,
#   'true': 28,
#   '😹😹😹😹😹😹😹😹😹😹😹okay': 1,
#   'happened': 3,
#   'chunin': 1,
#   'exams': 1,
#   'Boruto': 4,
#   'Meanwhile': 3,
#   'Naruto': 3,
#   'Gaara': 1,
#   'killing': 1,
#   'Orochimaru': 1,
#   'attacking': 1,
#   'see': 58,
#   'doing': 9,
#   'war': 10,
#   'If': 11,
#   'interesting': 9,
#   'make': 23,
#   'alien': 2,
#   'plots': 1,
#   'becomes': 1,
#   'DB': 1,
#   'Super': 1,
#   'Nobody': 2,
#   'them': 33,
#   'again': 9,
#   'say': 23,
#   'breed': 1,
#   'created': 2,
#   'Ishiki': 1,
#   'coming': 11,
#   'revenge': 2,
#   'move': 5,
#   'through': 5,
#   'space': 6,
#   'time': 22,
#   'an': 44,
#   'intergalactic': 1,
#   'tournament': 5,
#   "😹😹😹I'm": 2,
#   'wait': 5,
#   'song': 6,
#   'They': 19,
#   'released': 1,
#   'chips': 1,
#   'à': 7,
#   'MacBook': 1,
#   'Pro': 1,
#   'About': 2,
#   'hour': 1,
#   'ago': 2,
#   'watch': 28,
#   '😹😹😹😹😹😹😹😹': 20,
#   'tell': 5,
#   'him': 26,
#   '😹😹😹ahn': 1,
#   'ehhh': 4,
#   'Only': 1,
#   'wise': 1,
#   '😹😹😹who': 1,
#   'face': 7,
#   'home': 4,
#   'thought': 9,
#   'free': 4,
#   'anime': 14,
#   'chosen': 1,
#   'games': 13,
#   'more': 15,
#   'strategic': 1,
#   'tug': 1,
#   'bridge': 2,
#   '😹😹😹😹😹😹tsiups': 2,
#   'Unger': 1,
#   'pressure': 2,
#   'tactical': 2,
#   'Like': 13,
#   'two': 9,
#   'also': 27,
#   '☹️': 11,
#   'than': 20,
#   'honeycomb': 1,
#   'moved': 1,
#   'rails': 4,
#   'Put': 1,
#   'each': 4,
#   'rail': 1,
#   'moving': 7,
#   'Even': 18,
#   'glass': 2,
#   'distance': 5,
#   'smaller': 1,
#   'break': 4,
#   'walk': 1,
#   'done': 3,
#   'Marbles': 1,
#   'exchanged': 2,
#   'marbles': 4,
#   'And': 41,
#   'both': 4,
#   'win': 5,
#   'rule': 1,
#   '"Any': 1,
#   'person': 13,
#   'succeeds': 1,
#   'get': 8,
#   "partner's": 2,
#   'won"': 1,
#   'Each': 1,
#   'would': 8,
#   'Uncharted': 2,
#   'Trailer': 1,
#   'out': 26,
#   'film': 18,
#   'Tom': 1,
#   'Holland': 1,
#   'acting': 2,
#   'watched': 15,
#   'looks': 6,
#   "There's": 5,
#   'part': 16,
#   'where': 17,
#   'falss': 1,
#   'plan': 1,
#   'without': 6,
#   'parachute': 1,
#   '3': 16,
#   "don't": 25,
#   'data': 7,
#   'YouTube': 4,
#   'it🌚': 1,
#   'many': 23,
#   'things': 23,
#   "you've": 5,
#   'asked': 2,
#   'other': 25,
#   'ones': 6,
#   'Megalobox': 1,
#   'ehein': 3,
#   'thst': 1,
#   'episodes': 5,
#   '😹😹😹🤦🏾\u200d♂️': 4,
#   '😹😹🤦🏾\u200d♂️🤦🏾\u200d♂️': 1,
#   '😹😹😹oh': 1,
#   "they'll": 11,
#   'catch': 4,
#   'real': 6,
#   'prank': 2,
#   'day': 5,
#   'punish': 1,
#   "you'll": 19,
#   'lock': 3,
#   'jail': 1,
#   'What': 13,
#   'MCQ': 1,
#   'answer': 3,
#   'MCQs': 1,
#   'order': 2,
#   '1': 5,
#   'min': 1,
#   'per': 3,
#   'question': 4,
#   'questions': 2,
#   'less': 7,
#   'minute': 2,
#   'others': 2,
#   'take': 13,
#   'by': 14,
#   'skip': 2,
#   'Until': 1,
#   'reach': 2,
#   'That': 5,
#   'way': 16,
#   'save': 6,
#   'Ahnnn': 9,
#   '☹️😹😹': 1,
#   'sorry': 1,
#   'mistake': 2,
#   'chain': 1,
#   'video': 9,
#   "l'homme": 1,
#   'qui': 1,
#   'murmure': 1,
#   "l'oreille": 1,
#   'de': 2,
#   'jeux': 1,
#   'Naila': 4,
#   'hated': 1,
#   'pretending': 2,
#   'https//youtube/KwzJXmC9jF0': 1,
#   'laughing': 5,
#   'until': 1,
#   'daddy': 3,
#   'came': 8,
#   'check': 6,
#   'killed': 2,
#   '😹😹😹😹😹😹😹😹😹😹😹': 2,
#   'noticed': 1,
#   'videos': 3,
#   'watching': 13,
#   '🙌🏾🙌🏾': 4,
#   "\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾I'm": 1,
#   'Especially': 3,
#   'Cache': 1,
#   'switching': 1,
#   'weapons': 2,
#   '\U0001f90c🏾\U0001f90c🏾': 15,
#   'punches': 1,
#   'feel': 13,
#   'heavy': 2,
#   'joint': 1,
#   'pushed': 2,
#   'cache': 1,
#   'air': 3,
#   "He's": 9,
#   'Minato': 1,
#   'better': 15,
#   '🙌🏾🙌🏾🙌🏾': 1,
#   '😎😎😎': 1,
#   'Thank': 9,
#   'ST': 12,
#   '🥺🥺🙏🏾🙏🏾': 1,
#   'Jeune': 4,
#   'Padawan': 4,
#   'Now': 3,
#   'adult': 2,
#   '🤦🏾\u200d♂️🤦🏾\u200d♂️': 3,
#   'having': 4,
#   'struggles': 1,
#   'been': 16,
#   'saving': 1,
#   'pictures': 5,
#   '🎊🎉🎉😹😹': 1,
#   'sound': 1,
#   'rat': 1,
#   'though': 2,
#   'MC': 1,
#   'https//openspotifycom/track/1kvgnPAMyMI5E0B8XXQcSIsi=eut90z3bTD2wQgR0LdqLOw&utm_source=whatsapp': 1,
#   'yess': 1,
#   'Kakashi': 1,
#   'sharingan': 1,
#   'work': 12,
#   '😹😹😹😹oh': 1,
#   'eyyy😳': 1,
#   'hit': 2,
#   'your': 24,
#   'Atleast': 3,
#   'nobody': 5,
#   'got': 5,
#   'injury': 1,
#   'ashia': 2,
#   'call': 6,
#   'Projector': 1,
#   'supposed': 4,
#   'every': 4,
#   'stolen': 1,
#   'knife': 1,
#   'from': 37,
#   'boy': 2,
#   'checked': 2,
#   'saw': 14,
#   'fake': 1,
#   'avengers': 1,
#   'level': 4,
#   'threat': 1,
#   "That's": 30,
#   'always': 25,
#   'because': 29,
#   'likes': 1,
#   'steal': 1,
#   'knives': 1,
#   'wasting': 1,
#   'Oh': 10,
#   'easier': 1,
#   'turned': 1,
#   'year': 9,
#   'older': 4,
#   '_older_🌚': 1,
#   'ah😹😹': 1,
#   'pic': 1,
#   'told': 12,
#   'calling': 2,
#   'ringing': 1,
#   'idk': 4,
#   'agaim': 1,
#   "You're": 24,
#   'welcome': 19,
#   'mad': 17,
#   'ate': 1,
#   'tree': 3,
#   'My': 10,
#   'pocket': 1,
#   'took': 4,
#   'picture': 2,
#   'climbed': 1,
#   'want': 21,
#   'implicate': 1,
#   'pear': 2,
#   'does': 15,
#   'knew': 4,
#   'externals': 1,
#   'ride': 2,
#   '😅': 3,
#   'cleaned': 2,
#   'emptied': 1,
#   'uwc': 3,
#   "how's": 2,
#   'widow': 1,
#   'marvel': 2,
#   'abit': 14,
#   'formulas': 1,
#   'movies': 13,
#   "they're": 3,
#   'follow': 2,
#   'whole': 12,
#   'cinematic': 1,
#   'universe': 7,
#   'Better': 1,
#   'infinity': 4,
#   '🤔🤔': 1,
#   'streaming': 1,
#   'platforms': 1,
#   'cinema': 3,
#   'here': 20,
#   'showing': 4,
#   'Nasima': 3,
#   'cake': 5,
#   'sweet': 2,
#   'pizza': 2,
#   'burgers': 1,
#   'Karma': 1,
#   'Preaching': 1,
#   'words': 7,
#   'love': 2,
#   'God': 8,
#   'When': 10,
#   'conventionally': 1,
#   'preach': 1,
#   'defensive': 1,
#   'realize': 2,
#   'genuinely': 1,
#   'care': 2,
#   'open': 5,
#   'share': 3,
#   'vulnerabilities': 1,
#   'help': 3,
#   'December': 1,
#   '🌚🌚': 5,
#   '943': 2,
#   'am': 5,
#   'pm': 1,
#   'very': 28,
#   'good': 18,
#   'shots': 1,
#   'especially': 3,
#   'Casino': 1,
#   'scene': 4,
#   'saying': 17,
#   'scenes': 3,
#   'never': 12,
#   'thése': 1,
#   '\U0001f90c🏾\U0001f90c🏾😹😹': 1,
#   "he's": 23,
#   'fire': 5,
#   'drill😹': 1,
#   "😹😹😹😹I'm": 3,
#   'orchestrated': 1,
#   'exactly': 10,
#   'massa': 1,
#   '\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾': 1,
#   'dragon': 1,
#   'camera': 1,
#   '🙌🏾🌚': 1,
#   'really': 15,
#   'tomorrow': 3,
#   '😭': 5,
#   'Golden': 1,
#   'state': 2,
#   'title': 1,
#   'last': 14,
#   'playoffs': 1,
#   'before': 10,
#   'bottom': 1,
#   'league': 1,
#   'everyone': 9,
#   'heo': 1,
#   'Stephen': 1,
#   'Curry': 1,
#   'already': 11,
#   'old': 8,
#   'Venom': 4,
#   'Carnage': 2,
#   'bad': 3,
#   'finish': 5,
#   'movie': 22,
#   'script': 1,
#   'stupid': 2,
#   'look': 17,
#   'Free': 1,
#   'Guy': 1,
#   'trailers': 3,
#   'trust': 4,
#   'Sony': 3,
#   'Morbius': 1,
#   'Far': 1,
#   'Home': 2,
#   'Marvel': 8,
#   'Yeah': 5,
#   'thirsty': 1,
#   'desert': 2,
#   'shoes': 4,
#   '🥺': 13,
#   'eyes': 2,
#   'analyst': 1,
#   'FBI': 1,
#   'status': 6,
#   'doubt': 1,
#   'anything': 4,
#   'keeping': 2,
#   'secrets': 1,
#   'far': 8,
#   'multiverse': 2,
#   'Forwarded': 1,
#   'recieved': 1,
#   'frens': 1,
#   'lourdes': 1,
#   '6': 2,
#   'years': 9,
#   "You've": 2,
#   'met': 2,
#   '😹😹😹😹😹oh': 1,
#   'He': 13,
#   'Spider': 1,
#   'trailer': 6,
#   '\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾😹😹😹': 1,
#   'characters': 8,
#   'manage': 2,
#   'lizard': 1,
#   'sand': 1,
#   'electro': 1,
#   'Doc': 2,
#   'Ock': 2,
#   'Spiderman': 8,
#   'hard': 4,
#   'Tobey': 1,
#   "Maguire's": 1,
#   'villains': 3,
#   'plot': 3,
#   'everywhere': 2,
#   'introduction': 1,
#   'focus': 1,
#   'few': 2,
#   'character': 7,
#   'audience': 1,
#   'mind': 3,
#   'motivation': 1,
#   'kinds': 3,
#   'reason': 2,
#   "let's": 2,
#   '😹😹😹😹tsiups': 3,
#   'wehhh': 2,
#   'planning': 2,
#   'traveled': 2,
#   'Blossom': 3,
#   'eat': 4,
#   'fries': 1,
#   'months': 1,
#   'Congratulations': 2,
#   '🎊': 4,
#   '🎉': 1,
#   'full': 1,
#   'scholarship': 2,
#   '🤔': 4,
#   'makes': 7,
#   'Alright': 5,
#   '👌🏾': 4,
#   '😹😹😹😹😹😹😹😹😹😹': 4,
#   'wife': 1,
#   'child': 4,
#   'attack': 6,
#   'bday': 1,
#   "u'll": 3,
#   '20': 2,
#   'yrs': 1,
#   'Happy': 1,
#   'Birthday': 1,
#   '🎉🎊🎊': 1,
#   'May': 1,
#   'continue': 6,
#   'bless': 1,
#   'may': 1,
#   'find': 2,
#   'peace': 1,
#   'happiness': 1,
#   'prosperity': 1,
#   'endeavors': 1,
#   '🙏🏾': 1,
#   '🥺🥺': 2,
#   'Send': 1,
#   'going': 7,
#   'birthday': 2,
#   'almost': 4,
#   'forgot': 2,
#   'Arcane': 2,
#   'Attack': 5,
#   'Titan': 8,
#   'contact': 2,
#   'emoji': 4,
#   'wishing': 1,
#   'happy': 3,
#   'shld': 1,
#   'Silco': 1,
#   'reminds': 1,
#   'Klaus': 1,
#   'originals': 1,
#   'ending': 1,
#   '🥺🥺🥺😭😭😭': 1,
#   '17😹😹😹': 1,
#   'young': 2,
#   'cry': 2,
#   'Gumball': 1,
#   '😹🤦🏾\u200d♂️': 2,
#   'guy': 1,
#   "what's": 7,
#   'wonderful': 2,
#   'paid': 1,
#   'Ahn': 2,
#   'holidays': 1,
#   'company': 2,
#   'Do': 5,
#   'type': 8,
#   'cheat': 1,
#   'code': 1,
#   'backyard': 1,
#   'basketball': 1,
#   'wheelchair': 1,
#   'dunking': 1,
#   'how😹': 1,
#   'TV': 3,
#   'house': 4,
#   'box': 1,
#   'spoiling': 1,
#   'Détective': 1,
#   'Conan': 1,
#   'comics': 2,
#   'reasons': 1,
#   'mangas': 2,
#   'music': 3,
#   'Ekko': 1,
#   'Jinx': 1,
#   'Fight': 1,
#   'epic': 1,
#   'In': 6,
#   'comic': 1,
#   'silence': 2,
#   'car': 1,
#   'horning': 1,
#   'cat': 4,
#   'screams': 1,
#   'https//wwwyoutubecom/watchv=PTqQkNCxYy4': 1,
#   'An': 1,
#   'traitor': 2,
#   'gone': 4,
#   'dark': 3,
#   'side': 4,
#   'structures': 1,
#   'algorithms': 2,
#   'soundtrack': 1,
#   'Hero': 1,
#   'Haikyuu': 3,
#   'Christlicher': 1,
#   'rap': 1,
#   'ein': 1,
#   'languages': 2,
#   'classes': 2,
#   'paradigms': 1,
#   'programming': 3,
#   'net': 1,
#   'core': 1,
#   'C#': 1,
#   'gcc': 1,
#   'compiler': 1,
#   'C/C++': 1,
#   'etc': 1,
#   '😹😹😹😹ashia': 1,
#   '🎊🎉🎉': 1,
#   'deadline': 1,
#   'accept': 1,
#   'animés': 1,
#   'nn': 1,
#   'stuff': 1,
#   '😹😹😹please': 1,
#   'Cowboy': 1,
#   'beebop': 1,
#   "It's": 56,
#   'group': 3,
#   'different': 14,
#   'present': 1,
#   'research': 2,
#   'paper': 3,
#   'field': 1,
#   'artificial': 2,
#   'intelligence': 2,
#   'week': 1,
#   'Today': 1,
#   'presenting': 2,
#   'Graph': 1,
#   'Convolution': 1,
#   'Networks': 1,
#   'https//youtube/fjZAgoxFKiQ': 1,
#   'numTails++': 2,
#   'problem': 5,
#   'Java': 7,
#   'Javascript': 3,
#   'percentage': 4,
#   'asking': 3,
#   'For': 6,
#   'heads': 3,
#   '(num_heads/(num_heads': 1,
#   '+': 8,
#   'num_tails))': 2,
#   '*': 2,
#   '100': 5,
#   'num_heads': 2,
#   'flipped': 2,
#   'coins': 4,
#   '(num_heads': 2,
#   'num_tails': 3,
#   '=': 9,
#   '100)': 2,
#   'tails': 1,
#   ...},
#  'ST': {'😂😂😂😂😂😂😂': 54,
#   'You': 57,
#   'repaired': 1,
#   'your': 21,
#   'phone': 4,
#   'Ahh': 86,
#   'For': 8,
#   'how': 38,
#   'much': 13,
#   'Which': 8,
#   'mark': 1,
#   'That': 19,
#   'is': 227,
#   'expensive': 3,
#   'na😂😂😂': 25,
#   'Or': 27,
#   'salary': 1,
#   'up': 23,
#   'to': 325,
#   'that': 247,
#   'or': 96,
#   'something': 90,
#   '🌚': 125,
#   'ok🤔': 2,
#   'Are': 24,
#   'you': 259,
#   'still': 41,
#   'working': 6,
#   'for': 90,
#   'accessy': 1,
#   'it': 266,
#   'a': 264,
#   'different': 17,
#   'company': 3,
#   'ok': 87,
#   '😂😂😂😂😂😂😂😂😂': 16,
#   'Oh': 49,
#   'oh': 55,
#   'Tu': 16,
#   'connetra': 1,
#   'LA': 1,
#   'tristesse': 1,
#   'jeune': 8,
#   'padawan': 12,
#   'Okay😂😂': 6,
#   'Spiderman': 13,
#   'peeling': 1,
#   'bitterleaf': 1,
#   'I': 349,
#   "don't": 66,
#   'know': 55,
#   '😂😂😂😂😂': 88,
#   'Ha': 34,
#   'ah': 30,
#   'what😂😂': 3,
#   '😂😂😂😂Tsuips': 11,
#   'Maybe': 10,
#   'back': 32,
#   'from': 41,
#   'slumber': 1,
#   'na': 94,
#   '😂😂': 190,
#   'journey': 1,
#   'region': 1,
#   'Wait': 11,
#   'lemme': 5,
#   'wear': 2,
#   'my': 63,
#   'headsets😂😂😂': 1,
#   'Yee': 1,
#   'Yes*': 2,
#   '😂😂😂cest': 1,
#   'terrible': 76,
#   'called': 12,
#   'during': 5,
#   'programming': 2,
#   'class': 8,
#   'My': 16,
#   'teacher': 6,
#   'thought': 20,
#   'was': 250,
#   'the': 627,
#   'AI': 4,
#   'telling': 18,
#   'me': 66,
#   'solution': 4,
#   'wrong': 4,
#   'Before': 1,
#   'told': 9,
#   'him': 39,
#   'no': 80,
#   'brother': 2,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 5,
#   'Because': 40,
#   'we': 26,
#   'use': 12,
#   'this': 87,
#   'app': 4,
#   'he': 109,
#   'created': 3,
#   'our': 4,
#   'work': 7,
#   'and': 203,
#   'assessments': 1,
#   'so': 42,
#   'whenever': 1,
#   'there': 44,
#   'will': 62,
#   'start': 10,
#   'screaming': 2,
#   'embarrass': 1,
#   'people': 70,
#   'they': 102,
#   'get': 20,
#   'right': 3,
#   'next': 6,
#   'So': 59,
#   'before': 8,
#   'mo': 1,
#   'He': 56,
#   'really': 45,
#   "didn't": 36,
#   'disturb': 1,
#   'since': 18,
#   'east': 3,
#   'lecture': 1,
#   '😂😂😂😂': 89,
#   "Wasn't": 1,
#   '*': 9,
#   'said': 23,
#   'could': 17,
#   'call': 10,
#   'if': 34,
#   'wanted': 13,
#   'but': 59,
#   'should': 20,
#   'not': 114,
#   'forget': 2,
#   'finish': 7,
#   'assignments': 3,
#   'Time*😂': 1,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 2,
#   'How': 16,
#   'abuse': 1,
#   '😂😂😂': 141,
#   'now': 18,
#   'are': 97,
#   'using': 11,
#   'Javascript': 5,
#   'We': 10,
#   'switch': 2,
#   'c++': 2,
#   'going': 35,
#   'end': 15,
#   'of': 170,
#   'term': 2,
#   'Then': 55,
#   'following': 2,
#   'terms': 1,
#   'be': 75,
#   'python': 2,
#   'Yes': 148,
#   'yes': 110,
#   'The': 60,
#   'very': 43,
#   'nice': 46,
#   'And': 81,
#   'like': 135,
#   'explains': 1,
#   'can': 43,
#   'say': 14,
#   'skills': 1,
#   'have': 95,
#   'gone': 2,
#   'lot': 7,
#   'because': 43,
#   'even': 75,
#   'able': 3,
#   'find': 5,
#   'some': 25,
#   'problems': 3,
#   'in': 169,
#   'game': 30,
#   'helped': 1,
#   'What😂😂😂': 2,
#   "it's": 99,
#   'helping': 4,
#   'na🌚': 6,
#   'progress': 1,
#   'without': 4,
#   'paying': 2,
#   'someone': 14,
#   'help': 7,
#   'me🌚': 2,
#   'Have': 20,
#   'finished': 9,
#   'what': 47,
#   '500': 4,
#   'frs': 1,
#   'forfait😂': 1,
#   'Tsuips': 65,
#   'why': 36,
#   'does': 13,
#   'red': 3,
#   'cat': 3,
#   'defeat': 1,
#   'Jim': 1,
#   'Him*': 1,
#   'his': 60,
#   'weakness': 1,
#   'Mais': 1,
#   'il': 1,
#   'se': 1,
#   'releva': 1,
#   'encoure🎶🎶🎶🎶': 1,
#   'Tsuips😂😂😂😂😂😂': 1,
#   'Do': 7,
#   'remember': 18,
#   'where': 15,
#   'thing': 39,
#   'from😂😂': 1,
#   'yea😂😂😂😂😂😂😂😂': 1,
#   'It': 64,
#   'terrible😂😂😂😂': 1,
#   '😂😂😂😂😂😂😂😂😂😂': 15,
#   'M': 5,
#   'used': 13,
#   'eating': 4,
#   'sandwich': 2,
#   'then': 28,
#   'when': 50,
#   'blinks': 1,
#   'disappear': 2,
#   'with': 74,
#   'says': 1,
#   'M😂😂😂': 1,
#   'With': 9,
#   'paper*': 1,
#   '😂😂😂😂😂😂😂😂Tsuips': 5,
#   'Tampico': 1,
#   'never': 9,
#   'person': 12,
#   'begin': 1,
#   '🤦🏾\u200d♂️😂😂😂😂😂😂': 1,
#   'Cest': 4,
#   'vraiment': 1,
#   'No': 83,
#   'surely': 3,
#   'just': 158,
#   'made': 20,
#   'mistake': 3,
#   '😂😂😂😂😂😂': 80,
#   'Levi': 3,
#   'John': 3,
#   'wick': 3,
#   'attack': 16,
#   'on': 93,
#   'Titan': 11,
#   'Like': 32,
#   'always': 20,
#   'talking': 6,
#   'about': 47,
#   'Very': 1,
#   'soon': 9,
#   '"I': 1,
#   'saw': 9,
#   'kill': 5,
#   'fhuking': 1,
#   'pencil"😂😂😂': 1,
#   'thag': 3,
#   'Russian': 1,
#   'accent': 1,
#   'That*': 2,
#   '😂😂😂😂😂😂😂😂': 30,
#   'Why': 29,
#   'window': 1,
#   'wallpapers': 2,
#   'This': 35,
#   'nature': 1,
#   'automatically': 2,
#   'come': 12,
#   'windows': 1,
#   'computers': 2,
#   'desoia': 1,
#   'Attack': 2,
#   'season': 7,
#   '4': 9,
#   'part': 18,
#   '2': 9,
#   'trailer': 7,
#   'released': 5,
#   '😂😂😂\U0001f90c🏾🔥': 4,
#   'Heeeeh': 9,
#   'ehhhhhh': 1,
#   'Heeeeeeh': 1,
#   'ehhhhh': 1,
#   'message': 10,
#   'deleted': 6,
#   'Jeune': 4,
#   'any': 14,
#   "data😂😂I'm": 1,
#   'presently': 5,
#   'school': 18,
#   'notification': 1,
#   'at': 50,
#   'bus': 2,
#   'stop': 3,
#   'Okay😂\U0001f90c🏾': 1,
#   'seen': 20,
#   'it😂😂': 6,
#   'Even': 20,
#   'eh': 28,
#   "It's": 112,
#   'instead': 3,
#   'supposed': 3,
#   'opposite': 1,
#   '😂': 117,
#   "Didn't": 3,
#   'see': 40,
#   'What': 17,
#   'expect': 1,
#   'Haaa': 1,
#   'ahh😂😂': 1,
#   'intro': 1,
#   'trailer😂\U0001f90c🏾🔥': 1,
#   '😂😂😂😂ha': 8,
#   'What🌚': 4,
#   'new': 9,
#   'favorite': 2,
#   'sticker😂😂': 1,
#   'dayebga': 2,
#   'terrible😂😂😂😂😂😂': 1,
#   'started': 12,
#   'laughing': 5,
#   'aloud': 1,
#   'she': 18,
#   'Nathaniel': 5,
#   'hiring': 1,
#   'watch': 33,
#   'Since': 5,
#   'identity': 1,
#   '😂🌚': 2,
#   'nothing': 10,
#   'these': 13,
#   'things': 27,
#   'young': 5,
#   'fooling': 1,
#   'all': 48,
#   'cer': 1,
#   'regular': 1,
#   'show': 16,
#   'baby': 1,
#   '100': 5,
#   'years': 9,
#   'old😂😂😂': 2,
#   'Tsiups': 2,
#   'Tsuipsje': 1,
#   'vais': 2,
#   'te': 2,
#   'robam': 2,
#   'Je*': 1,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 5,
#   'think': 22,
#   "I'm": 96,
#   'mad': 5,
#   "I'll": 33,
#   'try': 16,
#   'one': 58,
#   'day': 8,
#   'record': 1,
#   'camera': 7,
#   'Okay': 37,
#   'On': 5,
#   'computer😂😂😂': 1,
#   'did': 33,
#   'daddy': 8,
#   'say😂😂': 1,
#   'Ure': 1,
#   'making': 5,
#   'anime': 11,
#   'haikyuu': 1,
#   'Okay😂😂😂😂': 1,
#   'visor': 1,
#   'na😂😂😂😂': 2,
#   'Video': 1,
#   'luck': 1,
#   'Eh😂😂😂😂': 2,
#   'How😂😂': 2,
#   'episode': 11,
#   'galactic': 1,
#   'football': 1,
#   'Where': 6,
#   'girl': 1,
#   'landed': 2,
#   'sprained': 1,
#   'her': 9,
#   'leg': 2,
#   'She': 8,
#   'goal': 1,
#   'keeper': 1,
#   'ashia': 4,
#   'left': 6,
#   'side': 3,
#   'foot': 1,
#   'legs': 3,
#   'ppaini': 1,
#   "I've": 42,
#   'been': 29,
#   'skateboarding': 1,
#   'whole': 25,
#   'week': 4,
#   'Paining': 1,
#   'finally': 3,
#   'got': 14,
#   'jump': 1,
#   'cannot': 16,
#   'do': 37,
#   'too': 27,
#   'many': 17,
#   'tricks': 1,
#   '17': 1,
#   'dollars': 5,
#   'no😂😂': 3,
#   'Just': 7,
#   'neighborhood': 1,
#   'yes😂': 4,
#   'far': 7,
#   'hard': 1,
#   'Especially': 6,
#   'hills': 1,
#   '🤦🏾\u200d♂️': 16,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 1,
#   'People': 9,
#   'Please': 10,
#   'video': 17,
#   '😂😂😂thank': 1,
#   'true': 15,
#   'But': 108,
#   'peace': 1,
#   'na😂': 40,
#   'happen': 4,
#   'again': 20,
#   'They': 40,
#   'need': 19,
#   'destruction': 1,
#   'Konoha': 1,
#   'plot': 11,
#   'Case😂😂': 1,
#   'Now': 4,
#   'ishiki': 1,
#   'dead': 8,
#   'go': 21,
#   'normal': 6,
#   'jutsu': 1,
#   'stuff': 3,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 4,
#   'Tsuips😂😂😂😂': 1,
#   'no😂😂😂': 7,
#   'sure': 16,
#   'no😂': 1,
#   '😂the': 1,
#   'song': 3,
#   'funniest': 1,
#   'it😂😂😂': 3,
#   'Je': 3,
#   'send': 8,
#   'house': 11,
#   'network': 4,
#   'slow': 1,
#   'happened😂😂': 1,
#   'Eh😂': 5,
#   'Ok': 19,
#   'batman': 20,
#   'trailer😂😂😂😂😂\U0001f90c🏾🔥': 1,
#   'felt': 6,
#   'arkham': 3,
#   'knight': 3,
#   '😂😂😂\U0001f90c🏾': 3,
#   'bike': 2,
#   'shoes': 3,
#   'confused': 6,
#   'Mob': 1,
#   'psycho': 1,
#   '3': 10,
#   'out😂😂\U0001f90c🏾\U0001f90c🏾\U0001f90c🏾🔥': 1,
#   'ehhhh': 8,
#   '2022is': 1,
#   'wonderful': 1,
#   'year': 7,
#   '😂😂😂😂😂\U0001f90c🏾\U0001f90c🏾': 1,
#   'Is*': 1,
#   'she/her': 1,
#   'thing😂😂': 1,
#   'here': 11,
#   'it😂': 6,
#   '😂😂😂😂😂😂Tsuips': 10,
#   'who': 24,
#   '😂😂😂😂😂😂he': 1,
#   'ne': 9,
#   'sais': 5,
#   'rien': 7,
#   'an': 31,
#   'reface': 1,
#   'What😂😂😂😂😂😂': 1,
#   'must': 2,
#   'friends': 4,
#   'were': 49,
#   'asking': 7,
#   'Going': 1,
#   'groups': 1,
#   'alone': 2,
#   "wasn't": 21,
#   'another': 5,
#   'everyone': 13,
#   "they're": 2,
#   'buy': 7,
#   'tickets': 1,
#   'which': 17,
#   'cold': 1,
#   'outside': 2,
#   'fall': 3,
#   'has': 38,
#   'hands': 1,
#   'almost': 6,
#   'froze': 1,
#   'morning': 3,
#   'imagine': 4,
#   'night': 2,
#   'Noo😂😂': 4,
#   '25': 1,
#   'ticket': 2,
#   'sticker': 6,
#   "You've": 4,
#   'watched': 20,
#   'it😂😂😂😂': 3,
#   'ending': 3,
#   'fought': 1,
#   'best': 17,
#   'friend': 4,
#   'bit': 7,
#   'Kakashi': 1,
#   'obito': 1,
#   'https//youtube/1oPMw8ftL6w': 2,
#   'Dayebga': 16,
#   'man': 13,
#   'fight': 10,
#   'director': 2,
#   'Shang': 6,
#   'chi': 6,
#   'legend': 1,
#   'ten': 1,
#   'rings': 1,
#   'makes': 10,
#   'choreography': 1,
#   'videos': 1,
#   'animes': 2,
#   "That's": 33,
#   'saying': 23,
#   'legendary': 1,
#   'scenes': 6,
#   '😂\U0001f90c🏾🔥': 1,
#   'anime😂': 1,
#   'also': 50,
#   'Chadwick': 2,
#   'bosemans': 2,
#   'stunt': 2,
#   'double': 2,
#   'captain': 5,
#   'America': 2,
#   'civil': 2,
#   'war': 14,
#   'strategy': 3,
#   'wws': 2,
#   'trying': 8,
#   'survive': 3,
#   'Realistically': 1,
#   'would': 26,
#   'done': 5,
#   'same': 27,
#   'as': 29,
#   'them': 32,
#   'Ahh😂': 1,
#   'went': 10,
#   'more': 16,
#   'games': 13,
#   'put': 15,
#   'under': 5,
#   'pressure': 1,
#   'than': 8,
#   'make': 26,
#   'strategic': 1,
#   'audience': 1,
#   'feel': 8,
#   'afraid': 5,
#   'characters': 7,
#   "you're": 10,
#   'plan': 5,
#   'might': 8,
#   'bridge': 2,
#   'every': 5,
#   'himself': 1,
#   'pushing': 2,
#   'most': 9,
#   'tactical': 1,
#   'tug': 1,
#   'o': 1,
#   'intelligent': 1,
#   'pushed': 2,
#   'looking': 5,
#   'glass': 4,
#   'terrible😂': 1,
#   'other': 23,
#   'refusing': 2,
#   'move': 7,
#   'ahead': 2,
#   'top': 4,
#   'rails': 1,
#   'Go': 1,
#   'waghc': 2,
#   'myself': 4,
#   'question': 6,
#   'large': 1,
#   'strerch': 1,
#   'their': 20,
#   'time': 32,
#   'limit': 1,
#   'breaking': 1,
#   'Ahh😂😂😂': 2,
#   'want': 17,
#   'Imagine': 3,
#   'tension': 1,
#   '😂😂😂😂😂😂😂😂😂wait': 1,
#   'understand😂': 1,
#   'realize🤔': 1,
#   'look': 5,
#   'Is': 13,
#   'Okay😂😂😂': 1,
#   "haven't": 12,
#   'yet🌚': 3,
#   'Ok😂😂😂': 1,
#   'Heeeh': 16,
#   'ehh': 11,
#   '😂😂\U0001f90c🏾': 11,
#   'vinland': 2,
#   'saga': 2,
#   '😂😂😂ts': 1,
#   'Noo': 18,
#   'only': 25,
#   'boruto': 2,
#   'Kara': 1,
#   'arc': 4,
#   "😂😂😂😂😂😂it's": 3,
#   'ninja': 2,
#   'realize': 7,
#   'had': 39,
#   'stickers': 1,
#   '😂😂😂😂😂😂😂😂😂😂😂': 8,
#   'few': 2,
#   'minutes': 4,
#   'ago': 1,
#   'face': 6,
#   'samurai': 1,
#   'yee😂😂': 1,
#   'questions': 5,
#   'GCE': 1,
#   'Cameroon': 13,
#   'In': 11,
#   'weer': 1,
#   'given': 1,
#   '1hr': 1,
#   '30minw': 1,
#   'Mins*': 1,
#   'required': 1,
#   'thinking': 7,
#   'skipped': 1,
#   'ones': 3,
#   'answer': 6,
#   'outright': 1,
#   '48': 1,
#   'first': 20,
#   'place': 7,
#   'second': 7,
#   'writing': 2,
#   'ACT': 2,
#   'During': 1,
#   'wrote': 1,
#   '5': 5,
#   '27': 1,
#   '18': 3,
#   'maths': 1,
#   '36': 2,
#   'science': 2,
#   '23': 1,
#   'English': 10,
#   '24': 1,
#   'reading': 5,
#   '22': 2,
#   'total': 2,
#   'score': 3,
#   'highest': 2,
#   'basically': 5,
#   'scored': 1,
#   'average': 1,
#   'gotten': 2,
#   'everything': 19,
#   'hoping': 1,
#   'higher': 2,
#   '🤧': 1,
#   '😂😂😂😂it': 3,
#   'yet😂😂😂😂\U0001f90c🏾🔥': 1,
#   'rewatched': 3,
#   'it😂😂\U0001f90c🏾': 1,
#   'real': 6,
#   'life': 6,
#   'ever': 8,
#   'tu': 4,
#   'Manchester': 1,
#   'united': 1,
#   'undefeatable😂😂': 1,
#   'yes😂😂😂😂😂': 1,
#   'play': 13,
#   'everytime': 2,
#   'those': 19,
#   'Nero': 1,
#   'sections': 1,
#   "l'homme": 3,
#   'qui': 3,
#   'murmured': 1,
#   "l'oreille": 3,
#   'du': 2,
#   'vomit🌚': 2,
#   'naila': 6,
#   'vomited': 1,
#   'pillow': 1,
#   'na😂😂😂😂😂😂': 1,
#   'hate': 2,
#   'If': 14,
#   'hated': 3,
#   'welcome': 2,
#   'everyday': 1,
#   'came': 11,
#   'back🌚': 1,
#   'seeing': 24,
#   'let': 6,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂': 6,
#   'sleeping😂😂😂😂😂😂': 1,
#   'ribs': 1,
#   'broke': 1,
#   'sleep': 4,
#   'gasp': 1,
#   'air': 3,
#   'watching': 9,
#   '500k': 1,
#   'subscribers😂😂😂': 1,
#   '😂😂😂😂\U0001f90c🏾🔥': 1,
#   'its': 13,
#   'directed': 1,
#   'stunts': 1,
#   '\U0001f90c🏾🔥': 4,
#   'seeing\U0001f90c🏾😂😂😂': 1,
#   'As': 5,
#   'better': 12,
#   'action': 10,
#   'sequences': 2,
#   'anime😂😂': 1,
#   "You're": 7,
#   'Happy': 1,
#   'birthday': 1,
#   '🥳🥳🥳🥳🥳🎉🎉🎉😂😂🔥🔥': 1,
#   'king': 2,
#   'fighters': 1,
#   'rat': 1,
#   'fighting': 7,
#   'chicken': 1,
#   'na😂😂😂😂😂': 1,
#   '😂😂😂😂no': 4,
#   'Let': 4,
#   'listen': 3,
#   'thank': 23,
#   '😂\U0001f90c🏾': 9,
#   'segment': 1,
#   'playing': 6,
#   'traditional': 1,
#   'drums': 1,
#   'epic😂😂\U0001f90c🏾': 1,
#   '😂😂😂😂😂they': 2,
#   'besto': 1,
#   'friendo': 1,
#   'BRUTHA': 1,
#   "😂😂😂😂😂😂😂😂😂that's": 1,
#   'name': 10,
#   'decided': 6,
#   'change': 2,
#   'nose': 1,
#   'paining': 2,
#   'actually': 33,
#   'One': 4,
#   'knife': 3,
#   'Seriously🤦🏾\u200d♂️': 1,
#   'happened': 7,
#   'culinary': 2,
#   'classroom': 5,
#   'knives': 1,
#   'cook': 2,
#   'after': 6,
#   'rang': 1,
#   'bell': 1,
#   'passing': 1,
#   'beside': 2,
#   'two': 7,
#   'jumped': 1,
#   'into': 13,
#   'corridor': 3,
#   '🤷🏾\u200d♂️🤦🏾\u200d♂️': 1,
#   'elbow': 1,
#   'while': 7,
#   'separate': 1,
#   'Normally': 2,
#   "wouldn't": 4,
#   'interfered': 1,
#   'dangerous': 1,
#   'situation': 1,
#   'Thank': 19,
#   'you🤦🏾\u200d♂️😂😂😂': 1,
#   "there's": 7,
#   '😂😂😂😂😂Tsuips': 9,
#   'bombing': 1,
#   'threat': 2,
#   'There': 13,
#   'projector': 1,
#   'anything': 16,
#   'die': 9,
#   '🌚😂😂😂': 1,
#   'fast': 3,
#   'impressive': 1,
#   '🤔': 18,
#   '😂😂😂😂😂😂\U0001f90c🏾🔥': 1,
#   'ehhh😂😂😂': 1,
#   'MORBIUS': 2,
#   'trailer😂': 1,
#   'No😂😂😂': 1,
#   'improvise': 1,
#   'it🌚': 7,
#   'walking': 1,
#   'home': 11,
#   'Atleast': 2,
#   'battery': 1,
#   'aunty': 4,
#   'rose': 2,
#   'Call': 1,
#   'na🥺': 1,
#   'bathroom': 1,
#   '🥺': 7,
#   'calling': 1,
#   '😂😂😂😂😂😂😂Tsuips': 3,
#   'how😂😂😂': 1,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 2,
#   'picture': 6,
#   'tree': 2,
#   '😂😂😂😂😂😂😂😂nooo': 1,
#   'climbing': 1,
#   'madman': 1,
#   'boss': 2,
#   'probably': 21,
#   'fire': 2,
#   'All': 4,
#   'follow': 1,
#   'damn': 1,
#   'train': 2,
#   'CJ': 1,
#   'Wht🌚': 1,
#   'Yell': 2,
#   'out': 25,
#   'eat': 7,
#   'pear': 4,
#   'pain': 1,
#   'Pear': 1,
#   'ultimate': 1,
#   'fruit': 1,
#   'save': 3,
#   'universe': 9,
#   'knew': 2,
#   'emoji': 1,
#   'serious': 4,
#   'invented': 3,
#   'give': 9,
#   'super': 4,
#   'powers': 5,
#   'actual': 3,
#   'removed': 6,
#   'port': 2,
#   'pears': 2,
#   'ate': 3,
#   'gave': 8,
#   'today': 5,
#   "couldn't": 2,
#   'yesterday': 7,
#   'Mummy': 1,
#   'hover': 1,
#   'board': 1,
#   'David': 1,
#   'bizzar': 4,
#   'theater': 3,
#   'wifi': 1,
#   'box': 2,
#   'reviews': 2,
#   'rotten': 2,
#   'tomato': 1,
#   'film': 5,
#   'By': 3,
#   'marvel': 10,
#   'good': 15,
#   'movie': 58,
#   'starts': 2,
#   'streaming': 1,
#   '45': 2,
#   'days': 2,
#   'initial': 1,
#   'release': 4,
#   '\U0001f90c🏾\U0001f90c🏾🔥🔥😂😂yes': 1,
#   'eaten': 1,
#   'cake': 2,
#   'months': 1,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 3,
#   'realized': 4,
#   'times': 6,
#   '😂😂😂\U0001f90c🏾\U0001f90c🏾🔥': 2,
#   'heeeh': 2,
#   'ehh😂😂': 1,
#   '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 1,
#   'unlocked': 1,
#   'mangekyo': 2,
#   'own': 6,
#   'running': 6,
#   'When': 9,
#   'walk': 2,
#   'sharingan😂😂😂': 1,
#   '943😂': 1,
#   'explaining': 1,
#   'shots': 1,
#   'movies': 9,
#   'black': 3,
#   'panther': 1,
#   'reference': 2,
#   'used*': 1,
#   'hours': 1,
#   'behind': 1,
#   'symbolism': 2,
#   'example': 2,
#   'killmonger': 3,
#   'arrested': 4,
#   'brought': 4,
#   'throne': 1,
#   'room': 1,
#   'pans': 1,
#   'upside': 2,
#   'down': 11,
#   'Wakanda': 2,
#   'turning': 1,
#   'taking': 4,
#   'over': 9,
#   'arrival': 1,
#   'turn': 6,
#   'upside-down': 1,
#   'subconsciously': 2,
#   'emotions': 3,
#   'tchalla': 1,
#   'waterfall': 1,
#   'angle': 1,
#   'shown': 2,
#   'above': 1,
#   'adds': 3,
#   'feeling': 7,
#   'worry': 2,
#   'anxiety': 1,
#   '"What': 1,
#   'happen"': 1,
#   '😂😂😂😂Cameroon': 1,
#   'teachers': 1,
#   '😂😂😂😂😂😂No': 1,
#   'randomly': 2,
#   'decide': 2,
#   'known': 1,
#   'His': 6,
#   'waiting': 5,
#   'opportunity': 1,
#   'impossible': 1,
#   'impeccable': 1,
#   '😂😂\U0001f90c🏾🔥': 2,
#   'eternals': 5,
#   'beat': 2,
#   'visuals': 1,
#   'eh\U0001f90c🏾🔥': 1,
#   'The*': 1,
#   'HD': 4,
#   'hero': 5,
#   'academia': 2,
#   'YouTube': 1,
#   'knows': 5,
#   'animes\U0001f90c🏾🔥😂': 1,
#   ...}}

# %%
# wordCount_df = pd.DataFrame.from_dict({(i,j): vocabulary[i][j] 
#                            for i in vocabulary.keys() 
#                            for j in vocabulary[i].keys()},
#                        orient='index')

# wordCount_df = pd.DataFrame.from_dict(vocabulary, orient='index')
series = [[person, word, vocabulary[person][word]] for person in vocabulary.keys() for word in vocabulary[person].keys()]


wordCount_df = pd.DataFrame(series, columns=['Person', 'Word', 'Count'])
wordCount_df
# Out:
#             Person      Word  Count
# 0     Babila Mutia       I'm     86
# 1     Babila Mutia      back     15
# 2     Babila Mutia         🌚    253
# 3     Babila Mutia        No     55
# 4     Babila Mutia         I    275
# ...            ...       ...    ...
# 6109            ST  username      1
# 6110            ST  underage      1
# 6111            ST   receive      1
# 6112            ST      bank      1
# 6113            ST    dollar      1
#
# [6114 rows x 3 columns]

# %%
wordCount_df[wordCount_df['Person'] == people[0]].sort_values(by='Count', ascending=False).reset_index(drop=True).iloc[0:25]
# Out:
#           Person    Word  Count
# 0   Babila Mutia     the    535
# 1   Babila Mutia       😹    505
# 2   Babila Mutia     😹😹😹    362
# 3   Babila Mutia      😹😹    348
# 4   Babila Mutia      it    293
# 5   Babila Mutia       I    275
# 6   Babila Mutia    that    265
# 7   Babila Mutia      to    261
# 8   Babila Mutia       🌚    253
# 9   Babila Mutia     you    235
# 10  Babila Mutia     was    211
# 11  Babila Mutia    😹😹😹😹    210
# 12  Babila Mutia     and    195
# 13  Babila Mutia       a    186
# 14  Babila Mutia      is    176
# 15  Babila Mutia    okay    170
# 16  Babila Mutia    it's    158
# 17  Babila Mutia      in    156
# 18  Babila Mutia      of    146
# 19  Babila Mutia    just    146
# 20  Babila Mutia     yes    145
# 21  Babila Mutia    they    141
# 22  Babila Mutia  tsiups    136
# 23  Babila Mutia      no    127
# 24  Babila Mutia    like    125

# %%
wordCount_df[wordCount_df['Person'] == people[1]].sort_values(by='Count', ascending=False).reset_index(drop=True).iloc[0:25]
# Out:
#    Person  Word  Count
# 0      ST   the    627
# 1      ST     I    349
# 2      ST    to    325
# 3      ST    it    266
# 4      ST     a    264
# 5      ST   you    259
# 6      ST   was    250
# 7      ST  that    247
# 8      ST    is    227
# 9      ST   and    203
# 10     ST    😂😂    190
# 11     ST    of    170
# 12     ST    in    169
# 13     ST  just    158
# 14     ST   Yes    148
# 15     ST   😂😂😂    141
# 16     ST  like    135
# 17     ST     🌚    125
# 18     ST     😂    117
# 19     ST   not    114
# 20     ST  It's    112
# 21     ST   yes    110
# 22     ST    he    109
# 23     ST   But    108
# 24     ST  they    102
